# %%
import pandas as pd

# %%
#get good links from r
city_links = pd.read_csv("city_tables.csv")
city_links.head()
# Out:
#                          location        lat        lon  \
# 0          Alert, Nunavut, Canada  82.500000 -62.333333
# 1        Nord, Greenland, Denmark  81.600000 -16.666667
# 2         Eureka, Nunavut, Canada  79.983333 -85.933333
# 3    Ny-Ålesund, Svalbard, Norway  78.916667  11.933333
# 4  Longyearbyen, Svalbard, Norway  78.216667  15.650000
#
#                                             link
# 0   https://en.wikipedia.org/wiki/Alert,_Nunavut
# 1  https://en.wikipedia.org/wiki/Nord,_Greenland
# 2  https://en.wikipedia.org/wiki/Eureka,_Nunavut
# 3  https://en.wikipedia.org/wiki/Ny-%C3%85lesund
# 4     https://en.wikipedia.org/wiki/Longyearbyen

# %%
#define empty dataframe
climate_columns = ['Month', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Year','location','lat','lon']
climate_tables = pd.DataFrame(columns = climate_columns)
climate_tables
# Out:
# Empty DataFrame
# Columns: [Month, Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec, Year, location, lat, lon]
# Index: []

# %%
#test
df = pd.read_html(city_links.loc[0,"link"], match="[Rr]ecord [Hh]igh", encoding = 'str', header = 1)[0].dropna(axis=0, how='any')
# df['city'] = city_links.loc[0,"City"]
# df['country'] = city_links.loc[0,"Country"]
# list(df)[0]
df['location'] = city_links.loc[0,"location"]
df['lat'] = city_links.loc[0,"lat"]
df['lon'] = city_links.loc[0,"lon"]
df
# Out:
#                                     Month            Jan            Feb  \
# 0                     Record high humidex            0.0            0.0
# 1                     Record high °C (°F)       0.0 (32)       1.1 (34)
# 2                    Average high °C (°F)  −28.6 (−19.5)  −29.4 (−20.9)
# 3                      Daily mean °C (°F)    −32.2 (−26)  −33.2 (−27.8)
# 4                     Average low °C (°F)  −35.8 (−32.4)  −37.0 (−34.6)
# 5                      Record low °C (°F)    −48.9 (−56)    −50.0 (−58)
# 6                   Record low wind chill          −64.7          −60.5
# 7       Average precipitation mm (inches)    7.2 (0.283)    7.0 (0.276)
# 8            Average rainfall mm (inches)        0.0 (0)        0.0 (0)
# 9            Average snowfall cm (inches)     9.0 (3.54)     8.1 (3.19)
# 10  Average precipitation days (≥ 0.2 mm)            9.0            7.7
# 11          Average rainy days (≥ 0.2 mm)            0.0            0.0
# 12          Average snowy days (≥ 0.2 cm)            9.1            8.6
# 13          Average relative humidity (%)           66.8           66.6
# 14            Mean monthly sunshine hours            0.0            0.0
#
#               Mar            Apr            May           Jun           Jul  \
# 0            −2.4           −1.1            6.6          18.1          19.4
# 1       −2.2 (28)    −0.2 (31.6)      10.0 (50)   18.2 (64.8)     20.0 (68)
# 2   −28.4 (−19.1)   −20.4 (−4.7)    −8.4 (16.9)    2.0 (35.6)      6.1 (43)
# 3   −32.4 (−26.3)  −24.3 (−11.7)   −11.5 (11.3)   −0.4 (31.3)    3.4 (38.1)
# 9   184.6 (72.68)  Alert, Nunavut, Canada  82.5 -62.333333
# 10          106.1  Alert, Nunavut, Canada  82.5 -62.333333
# 11           10.6  Alert, Nunavut, Canada  82.5 -62.333333
# 12          108.0  Alert, Nunavut, Canada  82.5 -62.333333
# 13           75.8  Alert, Nunavut, Canada  82.5 -62.333333
# 14         1901.6  Alert, Nunavut, Canada  82.5 -62.333333

# %%
len(city_links)
# Out:
# 1149

# %%
for x in range(0,len(city_links)):
    try:
        df = pd.read_html(city_links.loc[x,"link"], match="[Rr]ecord [Hh]igh", encoding = 'str', header = 1)[0].dropna(axis=0, how='any')
        if list(df)[0]=="Month":
            df['location'] = city_links.loc[x,"location"]
            df['lat'] = city_links.loc[x,"lat"]
            df['lon'] = city_links.loc[x,"lon"]
            climate_tables = climate_tables.append(df, ignore_index=True)
    except:
        pass
climate_tables.head()
# Out:
#                   Month            Jan            Feb            Mar  \
# 0   Record high humidex            0.0            0.0           −2.4
# 1   Record high °C (°F)       0.0 (32)       1.1 (34)      −2.2 (28)
# 2  Average high °C (°F)  −28.6 (−19.5)  −29.4 (−20.9)  −28.4 (−19.1)
# 3    Daily mean °C (°F)    −32.2 (−26)  −33.2 (−27.8)  −32.4 (−26.3)
# 4   Average low °C (°F)  −35.8 (−32.4)  −37.0 (−34.6)  −36.3 (−33.3)
#
#              Apr           May          Jun         Jul          Aug  \
# 0           −1.1           6.6         18.1        19.4         23.8
# 1    −0.2 (31.6)     10.0 (50)  18.2 (64.8)   20.0 (68)  19.5 (67.1)
# 2   −20.4 (−4.7)   −8.4 (16.9)   2.0 (35.6)    6.1 (43)   3.3 (37.9)
# 3  −24.3 (−11.7)  −11.5 (11.3)  −0.4 (31.3)  3.4 (38.1)   0.8 (33.4)
# 4  −28.1 (−18.6)   −14.5 (5.9)  −2.7 (27.1)  0.7 (33.3)  −1.8 (28.8)
#
#             Sep           Oct            Nov            Dec          Year  \
# 0           8.4           3.9           −1.1            1.4          23.8
# 1   11.2 (52.2)    5.3 (41.5)     0.6 (33.1)     3.2 (37.8)     20.0 (68)
# 2   −5.3 (22.5)   −15.3 (4.5)   −22.3 (−8.1)  −25.6 (−14.1)   −14.4 (6.1)
# 3   −8.4 (16.9)    −18.9 (−2)  −26.0 (−14.8)  −29.4 (−20.9)   −17.7 (0.1)
# 4  −11.5 (11.3)  −22.4 (−8.3)  −29.6 (−21.3)  −33.1 (−27.6)  −21.0 (−5.8)
#
#                  location   lat        lon
# 0  Alert, Nunavut, Canada  82.5 -62.333333
# 1  Alert, Nunavut, Canada  82.5 -62.333333
# 2  Alert, Nunavut, Canada  82.5 -62.333333
# 3  Alert, Nunavut, Canada  82.5 -62.333333
# 4  Alert, Nunavut, Canada  82.5 -62.333333

# %%
climate_tables.to_csv("climate_tables.csv")

# %% [markdown]
# need
